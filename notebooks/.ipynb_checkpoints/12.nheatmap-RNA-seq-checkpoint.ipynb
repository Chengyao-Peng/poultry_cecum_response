# %%
import pandas as pd
import os 
HERE = os. getcwd()
from scipy.spatial.distance import pdist

DATA_DIRECTORY = os.path.abspath(os.path.join(HERE, os.pardir, 'data'))

output_raw_species_excel_path = os.path.join(DATA_DIRECTORY, 'interim', 'new_GTDB_species_raw_abundance.xlsx')
output_relative_species_excel_path = os.path.join(DATA_DIRECTORY, 'interim', 'new_GTDB_species_relative_abundance_filterd_low.xlsx')
mpa_report = os.path.join(DATA_DIRECTORY, 'interim', 'fM35A1_mpa_tax_report.txt')



species_id_name_dict_path = os.path.join(DATA_DIRECTORY, 'raw', 'GTDB_species_id_name_dict.pkl')
genus_id_name_dict_path = os.path.join(DATA_DIRECTORY, 'raw', 'GTDB_genus_id_name_dict.pkl') 

metadata_path = os.path.join(DATA_DIRECTORY, 'raw', 'uBIOMin_SAMPLE_MAP.xlsx' )

# %% [markdown]
# # 1.1 Load the data

# %%
metadata = pd.read_excel(metadata_path, header=0, index_col=0)
metadata
# Out:
#                           SAMPLE_ID SAMPLED_BIRD_ID GUT_SECTION     TYPE  \
# MOCK_ID
# CTR_D14_Cecum_Digesta_1      cD14A1           D14A1       Cecum  Digesta
# CTR_D14_Cecum_Digesta_2      cD14A2           D14A2       Cecum  Digesta
# CTR_D14_Cecum_Digesta_3      cD14A3           D14A3       Cecum  Digesta
# CTR_D14_Cecum_Digesta_4      cD14A4           D14A4       Cecum  Digesta
# DC_D14_Cecum_Digesta_1       cD14B1           D14B1       Cecum  Digesta
# ...                             ...             ...         ...      ...
# HBT_D03_Swab_Sampled_4        sS3E4            D3E4        Swab  Sampled
# DC-HBT_D03_Swab_Sampled_1     sS3F1            D3F1        Swab  Sampled
# DC-HBT_D03_Swab_Sampled_2     sS3F2            D3F2        Swab  Sampled
# DC-HBT_D03_Swab_Sampled_3     sS3F3            D3F3        Swab  Sampled
# DC-HBT_D03_Swab_Sampled_4     sS3F4            D3F4        Swab  Sampled
#
#                              AGE TREATMENT  MGX  MTX  SCFA  \
# MOCK_ID
# CTR_D14_Cecum_Digesta_1    Day14       CTR    1    2     1
# CTR_D14_Cecum_Digesta_2    Day14       CTR    1    2     1
# CTR_D14_Cecum_Digesta_3    Day14       CTR    1    2     1
# CTR_D14_Cecum_Digesta_4    Day14       CTR    1    2     1
# DC_D14_Cecum_Digesta_1     Day14        DC    1    2     1
# ...                          ...       ...  ...  ...   ...
# HBT_D03_Swab_Sampled_4     Day03       HBT    1    0     0
# DC-HBT_D03_Swab_Sampled_1  Day03    DC-HBT    1    0     0
# DC-HBT_D03_Swab_Sampled_2  Day03    DC-HBT    1    0     0
# DC-HBT_D03_Swab_Sampled_3  Day03    DC-HBT    1    0     0
# DC-HBT_D03_Swab_Sampled_4  Day03    DC-HBT    1    0     0
#
#                            BIOCRATES 500 data  BILE_SALTS  RNA_SEQ
# MOCK_ID
# CTR_D14_Cecum_Digesta_1                     0           1        0
# CTR_D14_Cecum_Digesta_2                     0           1        0
# CTR_D14_Cecum_Digesta_3                     0           1        0
# CTR_D14_Cecum_Digesta_4                     0           1        0
# DC_D14_Cecum_Digesta_1                      0           1        0
# ...                                       ...         ...      ...
# HBT_D03_Swab_Sampled_4                      0           0        0
# DC-HBT_D03_Swab_Sampled_1                   0           0        0
# DC-HBT_D03_Swab_Sampled_2                   0           0        0
# DC-HBT_D03_Swab_Sampled_3                   0           0        0
# DC-HBT_D03_Swab_Sampled_4                   0           0        0
#
# [751 rows x 12 columns]

# %%
mock_id_dict = dict(zip(metadata['SAMPLE_ID'], metadata.index))

# %%
import pickle5 as pickle

with open(species_id_name_dict_path, 'rb') as handle:
    species_id_name_dict=pickle.load(handle)
    

with open(genus_id_name_dict_path, 'rb') as handle:
    genus_id_name_dict=pickle.load(handle)

# %% [markdown]
# ## 1.2 Relative abundace + Bray-curtis distance

# %%
output_relative_species_excel = pd.read_excel(output_relative_species_excel_path, index_col=0)
output_relative_species_excel = output_relative_species_excel.loc[:, (output_relative_species_excel!= 0).any(axis=0)]

output_relative_species_excel = output_relative_species_excel.rename(index=mock_id_dict)

# %%
output_relative_species_excel
# Out:
#                            3022008677  1026330259  4154666852  871540697   \
# sampled_id
# CTR_D14_Cecum_Digesta_1           0.0         0.0         0.0         0.0
# CTR_D14_Cecum_Digesta_2           0.0         0.0         0.0         0.0
# CTR_D14_Cecum_Digesta_3           0.0         0.0         0.0         0.0
# CTR_D14_Cecum_Digesta_4           0.0         0.0         0.0         0.0
# DC_D14_Cecum_Digesta_1            0.0         0.0         0.0         0.0
# ...                               ...         ...         ...         ...
# AGP_D03_Colon_Mucosa_3            0.0         0.0         0.0         0.0
# DC-HBT_D03_Ileum_Mucosa_2         0.0         0.0         0.0         0.0
# AGP_D03_Colon_Mucosa_4            0.0         0.0         0.0         0.0
# HBT_D21_Swab_Marked_3             0.0         0.0         0.0         0.0
# DC-HBT_D03_Cecum_Mucosa_1         0.0         0.0         0.0         0.0
#
#                            2198975658  1256037754  1124992412  3766332478  \
# sampled_id
# CTR_D14_Cecum_Digesta_1           0.0         0.0         0.0         0.0
# CTR_D14_Cecum_Digesta_2           0.0         0.0         0.0         0.0
# CTR_D14_Cecum_Digesta_3           0.0         0.0         0.0         0.0
# CTR_D14_Cecum_Digesta_4           0.0         0.0         0.0         0.0
# DC_D14_Cecum_Digesta_1            0.0         0.0         0.0         0.0
# ...                               ...         ...         ...         ...
# AGP_D03_Colon_Mucosa_3            0.0         0.0         0.0         0.0
# DC-HBT_D03_Ileum_Mucosa_2         0.0         0.0         0.0         0.0
# AGP_D03_Colon_Mucosa_4            0.0         0.0         0.0         0.0
# HBT_D21_Swab_Marked_3             0.0         0.0         0.0         0.0
# DC-HBT_D03_Cecum_Mucosa_1         0.0         0.0         0.0         0.0
#
#                            2434605133  1449762941  ...  2573442458  \
# sampled_id                                         ...
# CTR_D14_Cecum_Digesta_1           0.0         0.0  ...     0.01128
# CTR_D14_Cecum_Digesta_2           0.0         0.0  ...     0.03066
# CTR_D14_Cecum_Digesta_3           0.0         0.0  ...     0.01904
# CTR_D14_Cecum_Digesta_4           0.0         0.0  ...     0.03696
# DC_D14_Cecum_Digesta_1            0.0         0.0  ...     0.02872
# ...                               ...         ...  ...         ...
# AGP_D03_Colon_Mucosa_3            0.0         0.0  ...     0.00000
# DC-HBT_D03_Ileum_Mucosa_2         0.0         0.0  ...     0.00000
# AGP_D03_Colon_Mucosa_4            0.0         0.0  ...     0.00000
# HBT_D21_Swab_Marked_3             0.0         0.0  ...     0.00000
# DC-HBT_D03_Cecum_Mucosa_1         0.0         0.0  ...     0.00000
#
#                            800752826   4022578758  340550719   3833276624  \
# sampled_id
# CTR_D14_Cecum_Digesta_1       0.02984     0.00250     0.01910     0.00011
# CTR_D14_Cecum_Digesta_2       0.00631     0.00139     0.03417     0.00017
# CTR_D14_Cecum_Digesta_3       0.01457     0.00035     0.00251     0.00017
# CTR_D14_Cecum_Digesta_4       0.00316     0.00022     0.01147     0.00020
# DC_D14_Cecum_Digesta_1        0.01867     0.00326     0.02677     0.00019
# ...                               ...         ...         ...         ...
# AGP_D03_Colon_Mucosa_3        0.00000     0.06769     0.00000     0.08893
# DC-HBT_D03_Ileum_Mucosa_2     0.00000     0.00000     0.00000     0.09339
# AGP_D03_Colon_Mucosa_4        0.00000     0.00000     0.00000     0.09922
# HBT_D21_Swab_Marked_3         0.00000     0.00000     0.00000     0.04947
# DC-HBT_D03_Cecum_Mucosa_1     0.00000     0.00000     0.00000     0.09022
#
#                            2706040429  4093283224  3842596132  1194449817  \
# sampled_id
# CTR_D14_Cecum_Digesta_1       0.02724     0.00057     0.01498     0.01208
# CTR_D14_Cecum_Digesta_2       0.00755     0.00022     0.00827     0.05971
# CTR_D14_Cecum_Digesta_3       0.03179     0.00093     0.00012     0.02336
# CTR_D14_Cecum_Digesta_4       0.01083     0.00047     0.00312     0.03359
# DC_D14_Cecum_Digesta_1        0.01268     0.00329     0.00101     0.02445
# ...                               ...         ...         ...         ...
# AGP_D03_Colon_Mucosa_3        0.00000     0.01334     0.00000     0.00000
# DC-HBT_D03_Ileum_Mucosa_2     0.00000     0.04981     0.00000     0.00000
# AGP_D03_Colon_Mucosa_4        0.00000     0.00000     0.00000     0.00000
# HBT_D21_Swab_Marked_3         0.00000     0.01889     0.00000     0.00000
# DC-HBT_D03_Cecum_Mucosa_1     0.00000     0.33094     0.00000     0.00000
#
#                            959440253
# sampled_id
# CTR_D14_Cecum_Digesta_1       0.00064
# CTR_D14_Cecum_Digesta_2       0.00081
# CTR_D14_Cecum_Digesta_3       0.00103
# CTR_D14_Cecum_Digesta_4       0.00105
# DC_D14_Cecum_Digesta_1        0.00109
# ...                               ...
# AGP_D03_Colon_Mucosa_3        0.51136
# DC-HBT_D03_Ileum_Mucosa_2     0.52347
# AGP_D03_Colon_Mucosa_4        0.54086
# HBT_D21_Swab_Marked_3         0.27908
# DC-HBT_D03_Cecum_Mucosa_1     0.43128
#
# [751 rows x 845 columns]

# %% [markdown]
# ### 1.2.0 all sample

# %%
all_samples_ids = output_relative_species_excel.index.tolist()

# %%
from scipy.spatial.distance import pdist

all_bray_curtis_condensed = pdist(output_relative_species_excel,metric='braycurtis')

# %%
from scipy.spatial.distance import squareform

all_bray_curtis_full = squareform(all_bray_curtis_condensed)

# %%
all_bray_curtis_full_df = pd.DataFrame(all_bray_curtis_full, index = all_samples_ids, columns=all_samples_ids)

# %%
all_dfrc=metadata.loc[output_relative_species_excel.index, ['GUT_SECTION', 'AGE', 'TREATMENT', 'TYPE']]
all_dfrc['GUT_SECTION'] = all_dfrc['GUT_SECTION'].str.replace('Swab', 'Cloaca')

# %%
# %pip install nheatmap
from nheatmap import nhm, scripts
g = nhm(data=all_bray_curtis_full_df)
fig, plots = g.run()
# Out:
# Requirement already satisfied: nheatmap in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: matplotlib>=3.0.3 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from nheatmap) (3.7.1)
# Requirement already satisfied: scipy>=1.3.1 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from nheatmap) (1.10.1)
# Requirement already satisfied: numpy>=1.17.2 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from nheatmap) (1.23.0)
# Requirement already satisfied: pandas>=0.25.1 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from nheatmap) (2.0.2)
# Requirement already satisfied: packaging in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from nheatmap) (23.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (4.40.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from pandas>=0.25.1->nheatmap) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from pandas>=0.25.1->nheatmap) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.3->nheatmap) (3.11.0)
# Requirement already satisfied: six>=1.5 in /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.3->nheatmap) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
output_relative_species_excel=output_relative_species_excel.fillna(value=0)

# %%
replace_dict = {"Ileum": "1. Ileum",
                "Cecum": "2. Cecum", 
                "Colon": "3. Colon", 
                "Cloaca":"4. Cloaca",
               "Digesta": "1. Digesta",
               "Mucosa/Tissue": "2. Mucosa/Tissue", 
               "Marked" : "3. Marked", 
               "Sampled" : "4. Sampled",
               "CTR": "1. CTR",
               "AGP": "2. AGP",
               "DC": "3. DC",
               "DC-AGP": "4. DC-AGP", 
               "HBT": "5. HBT",
               "DC-HBT": "6. DC-HBT"}
all_dfrc = all_dfrc.replace(to_replace=replace_dict)
all_dfrc.rename(columns={"GUT_SECTION": "Gut section", "AGE": "Age", "TREATMENT":"Treatment", "TYPE": "Type"})
# Out:
#                           Gut section    Age  Treatment              Type
# sampled_id
# CTR_D14_Cecum_Digesta_1      2. Cecum  Day14     1. CTR        1. Digesta
# CTR_D14_Cecum_Digesta_2      2. Cecum  Day14     1. CTR        1. Digesta
# CTR_D14_Cecum_Digesta_3      2. Cecum  Day14     1. CTR        1. Digesta
# CTR_D14_Cecum_Digesta_4      2. Cecum  Day14     1. CTR        1. Digesta
# DC_D14_Cecum_Digesta_1       2. Cecum  Day14      3. DC        1. Digesta
# ...                               ...    ...        ...               ...
# AGP_D03_Colon_Mucosa_3       3. Colon  Day03     2. AGP  2. Mucosa/Tissue
# DC-HBT_D03_Ileum_Mucosa_2    1. Ileum  Day03  6. DC-HBT  2. Mucosa/Tissue
# AGP_D03_Colon_Mucosa_4       3. Colon  Day03     2. AGP  2. Mucosa/Tissue
# HBT_D21_Swab_Marked_3       4. Cloaca  Day21     5. HBT         3. Marked
# DC-HBT_D03_Cecum_Mucosa_1    2. Cecum  Day03  6. DC-HBT  2. Mucosa/Tissue
#
# [751 rows x 4 columns]

# %%
cdendrogram_args = {'color_threshold':5.5}


g = nhm(data=all_bray_curtis_full_df, dfc=all_dfrc, figsize=(13, 10), linewidths=0, showyticks=False)
g.hcluster(method='average',optimal_ordering=True)
fig, plots = g.run()

# ax=fig.get_axes()[6]
# type(ax)
# # handles, labels = ax.get_legend_handles_labels()
# # handles
# # order = [0,2,1,3]
# # fig.legend([handles[idx] for idx in order],[labels[idx] for idx in order])

# ax = fig.gca()
# handles, labels = ax.get_legend_handles_labels()
# order = [0,2,1,3]
# fig.legend([handles[idx] for idx in order],[labels[idx] for idx in order])


# fig.savefig('../figures/heatmap_all_samples.png', bbox_inches='tight')
# Out:
# /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages/nheatmap/plot.py:254: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(df, method=method, metric=metric,
# /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages/nheatmap/plot.py:254: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(df, method=method, metric=metric,

# %%
# Out:
# [[<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >],
#  [<Axes: >, <Axes: ylabel='GUT_SECTION'>, <Axes: >, <Axes: >, <Axes: >],
#  [<Axes: >, <Axes: ylabel='AGE'>, <Axes: >, <Axes: >, <Axes: >],
#  [<Axes: >, <Axes: ylabel='TREATMENT'>, <Axes: >, <Axes: >, <Axes: >],
#  [<Axes: >, <Axes: ylabel='TYPE'>, <Axes: >, <Axes: >, <Axes: >],
#  [<Axes: >, <Axes: >, <Axes: >, <Axes: >, <Axes: >]]

# %% [markdown]
# ## 1.2.1 three base treatment

# %%
desired_prefixes=["CTR_D", "DC_D", "AGP_D"]
desired_type=['Digesta', 'Mucosa/Tissue']

three_basic_treatsment_dfrc = all_dfrc[all_dfrc.index.str.startswith(tuple(desired_prefixes))]
three_basic_treatsment_type_dfrc = three_basic_treatsment_dfrc[three_basic_treatsment_dfrc.TYPE.isin(desired_type)]
three_basic_treatsment_type_dfrc
# Out:
#                         GUT_SECTION    AGE TREATMENT           TYPE
# CTR_D14_Cecum_Digesta_1       Cecum  Day14       CTR        Digesta
# CTR_D14_Cecum_Digesta_2       Cecum  Day14       CTR        Digesta
# CTR_D14_Cecum_Digesta_3       Cecum  Day14       CTR        Digesta
# CTR_D14_Cecum_Digesta_4       Cecum  Day14       CTR        Digesta
# DC_D14_Cecum_Digesta_1        Cecum  Day14        DC        Digesta
# ...                             ...    ...       ...            ...
# DC_D03_Colon_Mucosa_4         Colon  Day03        DC  Mucosa/Tissue
# DC_D03_Colon_Mucosa_2         Colon  Day03        DC  Mucosa/Tissue
# DC_D03_Colon_Mucosa_3         Colon  Day03        DC  Mucosa/Tissue
# AGP_D03_Colon_Mucosa_3        Colon  Day03       AGP  Mucosa/Tissue
# AGP_D03_Colon_Mucosa_4        Colon  Day03       AGP  Mucosa/Tissue
#
# [277 rows x 4 columns]

# %%
three_basic_treatments_relative_species = output_relative_species_excel.loc[three_basic_treatsment_type_dfrc.index.tolist()]
three_basic_treatments_ids = three_basic_treatments_relative_species.index.tolist()
three_basic_treatments_bray_curtis_condensed = pdist(three_basic_treatments_relative_species,metric='braycurtis')
three_basic_treatments_bray_curtis_full = squareform(three_basic_treatments_bray_curtis_condensed)
three_basic_treatments_bray_curtis_full_df = pd.DataFrame(three_basic_treatments_bray_curtis_full, index = three_basic_treatments_ids, columns=three_basic_treatments_ids)


# mucosa_relative_species = output_relative_species_excel[['Mucosa' in s for s in output_relative_species_excel.index]]
# digesta_relative_species = output_relative_species_excel[['Digesta' in s for s in output_relative_species_excel.index]]

# %%
g = nhm(data=three_basic_treatments_bray_curtis_full_df, dfc=three_basic_treatsment_type_dfrc, figsize=(13, 10), linewidths=0, showyticks=False)
g.hcluster(method='average',optimal_ordering=True)
fig, plots = g.run()
fig.savefig('../figures/heatmap_three_basic_treatments_no_cloaca.png', bbox_inches='tight')
# Out:
# /home/chengyao/anaconda3/lib/python3.9/site-packages/nheatmap/plot.py:254: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(df, method=method, metric=metric,

# %% [markdown]
# ## 1.2.2 three base treatment digesta

# %%
three_basic_treatsment_digesta_dfrc = three_basic_treatsment_dfrc[three_basic_treatsment_dfrc.index.str.contains('Digesta')]

three_basic_treatsment_digesta_dfrc_index = three_basic_treatsment_digesta_dfrc.index.tolist()

three_basic_treatments_digesta_relative_species = three_basic_treatments_relative_species.loc[three_basic_treatsment_digesta_dfrc_index]

three_basic_treatments_digesta_ids = three_basic_treatments_digesta_relative_species.index.tolist()
three_basic_treatments_digesta_bray_curtis_condensed = pdist(three_basic_treatments_digesta_relative_species,metric='braycurtis')
three_basic_treatments_digesta_bray_curtis_full = squareform(three_basic_treatments_digesta_bray_curtis_condensed)
three_basic_treatments_digesta_bray_curtis_full_df = pd.DataFrame(three_basic_treatments_digesta_bray_curtis_full, index = three_basic_treatments_digesta_ids, columns=three_basic_treatments_digesta_ids)

# %%
g = nhm(data=three_basic_treatments_digesta_bray_curtis_full_df, dfc=three_basic_treatsment_digesta_dfrc, figsize=(13, 10), linewidths=0, showyticks=False)
g.hcluster(method='average',optimal_ordering=True)
fig, plots = g.run()
fig.savefig('../figures/heatmap_three_basic_treatments_digesta.png', bbox_inches='tight')
# Out:
# /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages/nheatmap/plot.py:254: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(df, method=method, metric=metric,
# /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages/nheatmap/plot.py:254: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(df, method=method, metric=metric,

# %% [markdown]
# ## 1.2.3 three base treatment cecum digesta day 35

# %%
three_basic_treatsment_digesta_day35_dfrc = three_basic_treatsment_dfrc[three_basic_treatsment_dfrc.index.str.contains('D35_Cecum_Digesta')]

three_basic_treatsment_digesta_day35_dfrc_index = three_basic_treatsment_digesta_day35_dfrc.index.tolist()

three_basic_treatments_digesta_day35_relative_species = three_basic_treatments_relative_species.loc[three_basic_treatsment_digesta_day35_dfrc_index]

three_basic_treatments_digesta_day35_ids = three_basic_treatments_digesta_day35_relative_species.index.tolist()
three_basic_treatments_digesta_day35_bray_curtis_condensed = pdist(three_basic_treatments_digesta_day35_relative_species,metric='braycurtis')
three_basic_treatments_digesta_day35_bray_curtis_full = squareform(three_basic_treatments_digesta_day35_bray_curtis_condensed)
three_basic_treatments_digesta_day35_bray_curtis_full_df = pd.DataFrame(three_basic_treatments_digesta_day35_bray_curtis_full, index = three_basic_treatments_digesta_day35_ids, columns=three_basic_treatments_digesta_day35_ids)

# %%
g = nhm(data=three_basic_treatments_digesta_day35_bray_curtis_full_df, dfc=three_basic_treatsment_digesta_day35_dfrc, figsize=(13, 10), linewidths=0, showyticks=False)
g.hcluster(method='average',optimal_ordering=True)
fig, plots = g.run()
fig.savefig('../figures/heatmap_three_basic_treatments_cecum_digesta_day35.png', bbox_inches='tight')
# Out:
# /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages/nheatmap/plot.py:254: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(df, method=method, metric=metric,
# /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages/nheatmap/plot.py:254: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(df, method=method, metric=metric,

# %% [markdown]
# ## 1.2.3 three base treatment colon digesta day 35

# %%
three_basic_treatsment_digesta_day35_dfrc = three_basic_treatsment_dfrc[three_basic_treatsment_dfrc.index.str.contains('D35_Colon_Digesta')]

three_basic_treatsment_digesta_day35_dfrc_index = three_basic_treatsment_digesta_day35_dfrc.index.tolist()

three_basic_treatments_digesta_day35_relative_species = three_basic_treatments_relative_species.loc[three_basic_treatsment_digesta_day35_dfrc_index]

three_basic_treatments_digesta_day35_ids = three_basic_treatments_digesta_day35_relative_species.index.tolist()
three_basic_treatments_digesta_day35_bray_curtis_condensed = pdist(three_basic_treatments_digesta_day35_relative_species,metric='braycurtis')
three_basic_treatments_digesta_day35_bray_curtis_full = squareform(three_basic_treatments_digesta_day35_bray_curtis_condensed)
three_basic_treatments_digesta_day35_bray_curtis_full_df = pd.DataFrame(three_basic_treatments_digesta_day35_bray_curtis_full, index = three_basic_treatments_digesta_day35_ids, columns=three_basic_treatments_digesta_day35_ids)

g = nhm(data=three_basic_treatments_digesta_day35_bray_curtis_full_df, dfc=three_basic_treatsment_digesta_day35_dfrc, figsize=(13, 10), linewidths=0, showyticks=False)
g.hcluster(method='average',optimal_ordering=True)
fig, plots = g.run()
fig.savefig('../figures/heatmap_three_basic_treatments_colon_digesta_day35.png', bbox_inches='tight')
# Out:
# /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages/nheatmap/plot.py:254: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(df, method=method, metric=metric,
# /home/chengyao/anaconda3/envs/chicken/lib/python3.9/site-packages/nheatmap/plot.py:254: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(df, method=method, metric=metric,

# %% [markdown]
# ### 1.2.1 Digesta and swab_sampled

# %%
digesta_swab_sampled_relative_species = output_relative_species_excel[output_relative_species_excel.index.str.contains('Digesta|Swab_Sampled')]

mucosa_relative_species = output_relative_species_excel[['Mucosa' in s for s in output_relative_species_excel.index]]
digesta_relative_species = output_relative_species_excel[['Digesta' in s for s in output_relative_species_excel.index]]

# %%
digesta_swab_sampled_relative_species
# Out:
#                             3465282864  2134035847  2706040429  2846587520  \
# CTR_D14_Cecum_Digesta_1        0.03619     0.02439     0.02724     0.01198
# CTR_D14_Cecum_Digesta_2        0.00694     0.00074     0.00755     0.00005
# CTR_D14_Cecum_Digesta_3        0.00441     0.00385     0.03179     0.00042
# CTR_D14_Cecum_Digesta_4        0.00648     0.05121     0.01083     0.00004
# DC_D14_Cecum_Digesta_1         0.00767     0.01334     0.01268     0.00005
# ...                                ...         ...         ...         ...
# DC-HBT_D03_Ileum_Digesta_2     0.00000     0.00000     0.00000     0.00000
# AGP_D03_Swab_Sampled_4         0.00000     0.00000     0.00000     0.00000
# DC_D03_Swab_Sampled_2          0.00000     0.00000     0.00000     0.00000
# DC-HBT_D03_Swab_Sampled_2      0.00000     0.00000     0.00000     0.00000
# CTR_D03_Swab_Sampled_4         0.00000     0.00000     0.00000     0.00000
#
#                             828666297   17238524    3174989685  1526722646  \
# CTR_D14_Cecum_Digesta_1        0.00809     0.00996     0.00560     0.00420
# CTR_D14_Cecum_Digesta_2        0.00147     0.00085     0.00138     0.00029
# CTR_D14_Cecum_Digesta_3        0.00711     0.00244     0.00926     0.00028
# CTR_D14_Cecum_Digesta_4        0.00157     0.00198     0.00653     0.00096
# DC_D14_Cecum_Digesta_1         0.00042     0.00117     0.00283     0.00015
# ...                                ...         ...         ...         ...
# DC-HBT_D03_Ileum_Digesta_2     0.00000     0.00000     0.00000     0.00000
# AGP_D03_Swab_Sampled_4         0.00000     0.00000     0.00000     0.00000
# DC_D03_Swab_Sampled_2          0.00000     0.00000     0.00000     0.00000
# DC-HBT_D03_Swab_Sampled_2      0.00000     0.00000     0.00000     0.00000
# CTR_D03_Swab_Sampled_4         0.00000     0.00000     0.00000     0.00000
#
#                             727000331   1719027312  ...  3875788747  \
# CTR_D14_Cecum_Digesta_1        0.00259     0.00267  ...         0.0
# CTR_D14_Cecum_Digesta_2        0.00050     0.00016  ...         0.0
# CTR_D14_Cecum_Digesta_3        0.17272     0.00018  ...         0.0
# CTR_D14_Cecum_Digesta_4        0.01103     0.00032  ...         0.0
# DC_D14_Cecum_Digesta_1         0.04029     0.00020  ...         0.0
# ...                                ...         ...  ...         ...
# DC-HBT_D03_Ileum_Digesta_2     0.00015     0.00000  ...         0.0
# AGP_D03_Swab_Sampled_4         0.00000     0.00000  ...         0.0
# DC_D03_Swab_Sampled_2          0.00000     0.00000  ...         0.0
# DC-HBT_D03_Swab_Sampled_2      0.00000     0.00000  ...         0.0
# CTR_D03_Swab_Sampled_4         0.00000     0.00000  ...         0.0
#
#                             4180186474  2801775871  2729612102  1114429988  \
# CTR_D14_Cecum_Digesta_1            0.0         0.0         0.0         0.0
# CTR_D14_Cecum_Digesta_2            0.0         0.0         0.0         0.0
# CTR_D14_Cecum_Digesta_3            0.0         0.0         0.0         0.0
# CTR_D14_Cecum_Digesta_4            0.0         0.0         0.0         0.0
# DC_D14_Cecum_Digesta_1             0.0         0.0         0.0         0.0
# ...                                ...         ...         ...         ...
# DC-HBT_D03_Ileum_Digesta_2         0.0         0.0         0.0         0.0
# AGP_D03_Swab_Sampled_4             0.0         0.0         0.0         0.0
# DC_D03_Swab_Sampled_2              0.0         0.0         0.0         0.0
# DC-HBT_D03_Swab_Sampled_2          0.0         0.0         0.0         0.0
# CTR_D03_Swab_Sampled_4             0.0         0.0         0.0         0.0
#
#                             3121632651  85380265    4035365926  2091774597  \
# CTR_D14_Cecum_Digesta_1            0.0         0.0         0.0         0.0
# CTR_D14_Cecum_Digesta_2            0.0         0.0         0.0         0.0
# CTR_D14_Cecum_Digesta_3            0.0         0.0         0.0         0.0
# CTR_D14_Cecum_Digesta_4            0.0         0.0         0.0         0.0
# DC_D14_Cecum_Digesta_1             0.0         0.0         0.0         0.0
# ...                                ...         ...         ...         ...
# DC-HBT_D03_Ileum_Digesta_2         0.0         0.0         0.0         0.0
# AGP_D03_Swab_Sampled_4             0.0         0.0         0.0         0.0
# DC_D03_Swab_Sampled_2              0.0         0.0         0.0         0.0
# DC-HBT_D03_Swab_Sampled_2          0.0         0.0         0.0         0.0
# CTR_D03_Swab_Sampled_4             0.0         0.0         0.0         0.0
#
#                             1618790722
# CTR_D14_Cecum_Digesta_1            0.0
# CTR_D14_Cecum_Digesta_2            0.0
# CTR_D14_Cecum_Digesta_3            0.0
# CTR_D14_Cecum_Digesta_4            0.0
# DC_D14_Cecum_Digesta_1             0.0
# ...                                ...
# DC-HBT_D03_Ileum_Digesta_2         0.0
# AGP_D03_Swab_Sampled_4             0.0
# DC_D03_Swab_Sampled_2              0.0
# DC-HBT_D03_Swab_Sampled_2          0.0
# CTR_D03_Swab_Sampled_4             0.0
#
# [367 rows x 3231 columns]

# %%
digesta_ids = digesta_relative_species.index.tolist()
mucosa_ids = mucosa_relative_species.index.tolist()
digesta_swab_sampled_ids = digesta_swab_sampled_relative_species.index.tolist()

# %%
from scipy.spatial.distance import pdist

# %%
digesta_bray_curtis_condensed = pdist(digesta_relative_species,metric='braycurtis')
mucosa_bray_curtis_condensed = pdist(mucosa_relative_species,metric='braycurtis')
digesta_swab_sampled_bray_curtis_condensed = pdist(digesta_swab_sampled_relative_species,metric='braycurtis')

# %%
from scipy.spatial.distance import squareform

digesta_bray_curtis_full = squareform(digesta_bray_curtis_condensed)
mucosa_bray_curtis_full = squareform(mucosa_bray_curtis_condensed)

digesta_swab_sampled_bray_curtis_full = squareform(digesta_swab_sampled_bray_curtis_condensed)

# %%
digesta_bray_curtis_full_df = pd.DataFrame(digesta_bray_curtis_full, index = digesta_ids, columns=digesta_ids)
mucosa_bray_curtis_full_df = pd.DataFrame(mucosa_bray_curtis_full, index = mucosa_ids, columns=mucosa_ids)

digesta_swab_sampled_bray_curtis_full_df = pd.DataFrame(digesta_swab_sampled_bray_curtis_full, index = digesta_swab_sampled_ids, columns=digesta_swab_sampled_ids)

# %%
digesta_dfrc=metadata.loc[digesta_relative_species.index, ['GUT_SECTION', 'AGE', 'TREATMENT']]
mucosa_dfrc=metadata.loc[mucosa_relative_species.index, ['GUT_SECTION', 'AGE', 'TREATMENT']]

digesta_swab_sampled_dfrc=metadata.loc[digesta_swab_sampled_relative_species.index, ['GUT_SECTION', 'AGE', 'TREATMENT']]
digesta_swab_sampled_dfrc['GUT_SECTION'] = digesta_swab_sampled_dfrc['GUT_SECTION'].str.replace('Swab', 'Cloaca')

# %%
# import hdbscan

# clusterer = hdbscan.HDBSCAN(allow_single_cluster=False,
#     approx_min_span_tree=True, gen_min_span_tree=True, min_cluster_size=4, metric='braycurtis')
# clusterer.fit(bray_curtis_full_df)

# %%
# clusterer.labels_

# %%
# dfrc['HDBSCAN_cluster']=clusterer.labels_
# dfrc['HDBSCAN_cluster']=dfrc['HDBSCAN_cluster'].apply(str)

# %%
# noise_metadata = dfrc[dfrc['HDBSCAN_cluster']=='-1']
# print(noise_metadata.shape)
# noise_metadata.sort_index()

# %%
# dfrc=dfrc.drop(index=noise_metadata.index.tolist())

# %%
# bray_curtis_full_noiseout_df= bray_curtis_full_df.drop(index=noise_metadata.index.tolist(),columns=noise_metadata.index.tolist())

# %%
# bray_curtis_full_noiseout_df

# %%
# %pip install nheatmap
from nheatmap import nhm, scripts
g = nhm(data=digesta_bray_curtis_full_df)
fig, plots = g.run()
# Out:
# Requirement already satisfied: nheatmap in /home/chengyao/anaconda3/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: packaging in /home/chengyao/anaconda3/lib/python3.9/site-packages (from nheatmap) (21.3)
# Requirement already satisfied: pandas>=0.25.1 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from nheatmap) (1.4.4)
# Requirement already satisfied: numpy>=1.17.2 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from nheatmap) (1.25.2)
# Requirement already satisfied: scipy>=1.3.1 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from nheatmap) (1.11.2)
# Requirement already satisfied: matplotlib>=3.0.3 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from nheatmap) (3.7.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (6.0.1)
# Requirement already satisfied: cycler>=0.10 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (0.11.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (9.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (1.1.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from matplotlib>=3.0.3->nheatmap) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from pandas>=0.25.1->nheatmap) (2022.1)
# Requirement already satisfied: zipp>=3.1.0 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=3.0.3->nheatmap) (3.8.0)
# Requirement already satisfied: six>=1.5 in /home/chengyao/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib>=3.0.3->nheatmap) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
rdendrogram_args = {'color_threshold':0.17}

# %%
digesta_relative_species=digesta_relative_species.fillna(value=0)
mucosa_relative_species=mucosa_relative_species.fillna(value=0)

digesta_swab_sampled_relative_species=digesta_swab_sampled_relative_species.fillna(value=0)

# digesta_relative_species=digesta_relative_species+0.0000001

# %%
cdendrogram_args = {'color_threshold':4}

g = nhm(data=digesta_bray_curtis_full_df, dfc=digesta_dfrc, figsize=(13, 10), linewidths=0, showyticks=False)
g.hcluster(method='average',optimal_ordering=True)
fig, plots = g.run(cdendrogram_args=cdendrogram_args)
fig.savefig('../figures/heatmap_digesta_samples.png', bbox_inches='tight')
# Out:
# /home/chengyao/anaconda3/lib/python3.9/site-packages/nheatmap/plot.py:254: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage = hierarchy.linkage(df, method=method, metric=metric,

# %%
digesta_bray_curtis_full_df
# Out:
#                             CTR_D14_Cecum_Digesta_1  CTR_D14_Cecum_Digesta_2  \
# CTR_D14_Cecum_Digesta_1                    0.000000                 0.520034
# CTR_D14_Cecum_Digesta_2                    0.520034                 0.000000
# CTR_D14_Cecum_Digesta_3                    0.593571                 0.619222
# CTR_D14_Cecum_Digesta_4                    0.540339                 0.475129
# DC_D14_Cecum_Digesta_1                     0.544807                 0.481471
# ...                                             ...                      ...
# HBT_D35_Ileum_Digesta_2                    0.976734                 0.984478
# HBT_D35_Ileum_Digesta_4                    0.965312                 0.976498
# HBT_D03_Ileum_Digesta_2                    0.979243                 0.986637
# CTR_D03_Ileum_Digesta_1                    0.985487                 0.988639
# DC-HBT_D03_Ileum_Digesta_2                 0.981708                 0.990720
#
#                             CTR_D14_Cecum_Digesta_3  CTR_D14_Cecum_Digesta_4  \
# CTR_D14_Cecum_Digesta_1                    0.593571                 0.540339
# CTR_D14_Cecum_Digesta_2                    0.619222                 0.475129
# CTR_D14_Cecum_Digesta_3                    0.000000                 0.614322
# CTR_D14_Cecum_Digesta_4                    0.614322                 0.000000
# DC_D14_Cecum_Digesta_1                     0.473346                 0.500040
# ...                                             ...                      ...
# HBT_D35_Ileum_Digesta_2                    0.977368                 0.979916
# HBT_D35_Ileum_Digesta_4                    0.964197                 0.972535
# HBT_D03_Ileum_Digesta_2                    0.973925                 0.984405
# CTR_D03_Ileum_Digesta_1                    0.978338                 0.990198
# DC-HBT_D03_Ileum_Digesta_2                 0.972901                 0.986209
#
#                             DC_D14_Cecum_Digesta_1  DC_D14_Cecum_Digesta_2  \
# CTR_D14_Cecum_Digesta_1                   0.544807                0.596991
# CTR_D14_Cecum_Digesta_2                   0.481471                0.651276
# CTR_D14_Cecum_Digesta_3                   0.473346                0.675591
# CTR_D14_Cecum_Digesta_4                   0.500040                0.629645
# DC_D14_Cecum_Digesta_1                    0.000000                0.645976
# ...                                            ...                     ...
# HBT_D35_Ileum_Digesta_2                   0.984698                0.977947
# HBT_D35_Ileum_Digesta_4                   0.972037                0.971507
# HBT_D03_Ileum_Digesta_2                   0.979805                0.985436
# CTR_D03_Ileum_Digesta_1                   0.988209                0.988729
# DC-HBT_D03_Ileum_Digesta_2                0.989070                0.988730
#
#                             DC_D14_Cecum_Digesta_3  DC_D14_Cecum_Digesta_4  \
# CTR_D14_Cecum_Digesta_1                   0.501183                0.502513
# CTR_D14_Cecum_Digesta_2                   0.584018                0.559077
# CTR_D14_Cecum_Digesta_3                   0.429684                0.571441
# CTR_D14_Cecum_Digesta_4                   0.569431                0.450651
# DC_D14_Cecum_Digesta_1                    0.434985                0.489885
# ...                                            ...                     ...
# HBT_D35_Ileum_Digesta_2                   0.981316                0.984569
# HBT_D35_Ileum_Digesta_4                   0.977146                0.975879
# HBT_D03_Ileum_Digesta_2                   0.983615                0.986708
# CTR_D03_Ileum_Digesta_1                   0.989818                0.990230
# DC-HBT_D03_Ileum_Digesta_2                0.990719                0.991801
#
#                             AGP_D14_Cecum_Digesta_1  AGP_D14_Cecum_Digesta_2  \
# CTR_D14_Cecum_Digesta_1                    0.531755                 0.469795
# CTR_D14_Cecum_Digesta_2                    0.511514                 0.478245
# CTR_D14_Cecum_Digesta_3                    0.692654                 0.492302
# CTR_D14_Cecum_Digesta_4                    0.481026                 0.506126
# DC_D14_Cecum_Digesta_1                     0.562237                 0.349755
# ...                                             ...                      ...
# HBT_D35_Ileum_Digesta_2                    0.979897                 0.974035
# HBT_D35_Ileum_Digesta_4                    0.974936                 0.967195
# HBT_D03_Ileum_Digesta_2                    0.986716                 0.976213
# CTR_D03_Ileum_Digesta_1                    0.991329                 0.982557
# DC-HBT_D03_Ileum_Digesta_2                 0.991550                 0.983539
#
#                             ...  HBT_D03_Ileum_Digesta_1  \
# CTR_D14_Cecum_Digesta_1     ...                 0.969470
# CTR_D14_Cecum_Digesta_2     ...                 0.982707
# CTR_D14_Cecum_Digesta_3     ...                 0.968965
# CTR_D14_Cecum_Digesta_4     ...                 0.973672
# DC_D14_Cecum_Digesta_1      ...                 0.969934
# ...                         ...                      ...
# HBT_D35_Ileum_Digesta_2     ...                 0.932203
# HBT_D35_Ileum_Digesta_4     ...                 0.895626
# HBT_D03_Ileum_Digesta_2     ...                 0.237956
# CTR_D03_Ileum_Digesta_1     ...                 0.681597
# DC-HBT_D03_Ileum_Digesta_2  ...                 0.780814
#
#                             HBT_D03_Ileum_Digesta_3  \
# CTR_D14_Cecum_Digesta_1                    0.967649
# CTR_D14_Cecum_Digesta_2                    0.975505
# CTR_D14_Cecum_Digesta_3                    0.951831
# CTR_D14_Cecum_Digesta_4                    0.972041
# DC_D14_Cecum_Digesta_1                     0.961921
# ...                                             ...
# HBT_D35_Ileum_Digesta_2                    0.931341
# HBT_D35_Ileum_Digesta_4                    0.852983
# HBT_D03_Ileum_Digesta_2                    0.508813
# CTR_D03_Ileum_Digesta_1                    0.389217
# DC-HBT_D03_Ileum_Digesta_2                 0.761627
#
#                             DC-HBT_D03_Ileum_Digesta_1  \
# CTR_D14_Cecum_Digesta_1                       0.978646
# CTR_D14_Cecum_Digesta_2                       0.982539
# CTR_D14_Cecum_Digesta_3                       0.973819
# CTR_D14_Cecum_Digesta_4                       0.983317
# DC_D14_Cecum_Digesta_1                        0.981068
# ...                                                ...
# HBT_D35_Ileum_Digesta_2                       0.962095
# HBT_D35_Ileum_Digesta_4                       0.953065
# HBT_D03_Ileum_Digesta_2                       0.849994
# CTR_D03_Ileum_Digesta_1                       0.829871
# DC-HBT_D03_Ileum_Digesta_2                    0.341930
#
#                             AGP_D35_Ileum_Digesta_2  \
# CTR_D14_Cecum_Digesta_1                    0.965141
# CTR_D14_Cecum_Digesta_2                    0.976158
# CTR_D14_Cecum_Digesta_3                    0.963157
# CTR_D14_Cecum_Digesta_4                    0.967834
# DC_D14_Cecum_Digesta_1                     0.976137
# ...                                             ...
# HBT_D35_Ileum_Digesta_2                    0.231689
# HBT_D35_Ileum_Digesta_4                    0.238460
# HBT_D03_Ileum_Digesta_2                    0.934202
# CTR_D03_Ileum_Digesta_1                    0.958564
# DC-HBT_D03_Ileum_Digesta_2                 0.934558
#
#                             DC-AGP_D35_Ileum_Digesta_4  \
# CTR_D14_Cecum_Digesta_1                       0.968873
# CTR_D14_Cecum_Digesta_2                       0.983218
# CTR_D14_Cecum_Digesta_3                       0.968187
# CTR_D14_Cecum_Digesta_4                       0.974025
# DC_D14_Cecum_Digesta_1                        0.976487
# ...                                                ...
# HBT_D35_Ileum_Digesta_2                       0.283642
# HBT_D35_Ileum_Digesta_4                       0.183406
# HBT_D03_Ileum_Digesta_2                       0.903074
# CTR_D03_Ileum_Digesta_1                       0.938151
# DC-HBT_D03_Ileum_Digesta_2                    0.914187
#
#                             HBT_D35_Ileum_Digesta_2  HBT_D35_Ileum_Digesta_4  \
# CTR_D14_Cecum_Digesta_1                    0.976734                 0.965312
# CTR_D14_Cecum_Digesta_2                    0.984478                 0.976498
# CTR_D14_Cecum_Digesta_3                    0.977368                 0.964197
# CTR_D14_Cecum_Digesta_4                    0.979916                 0.972535
# DC_D14_Cecum_Digesta_1                     0.984698                 0.972037
# ...                                             ...                      ...
# HBT_D35_Ileum_Digesta_2                    0.000000                 0.159590
# HBT_D35_Ileum_Digesta_4                    0.159590                 0.000000
# HBT_D03_Ileum_Digesta_2                    0.923718                 0.884890
# CTR_D03_Ileum_Digesta_1                    0.949622                 0.920980
# DC-HBT_D03_Ileum_Digesta_2                 0.939087                 0.923538
#
#                             HBT_D03_Ileum_Digesta_2  CTR_D03_Ileum_Digesta_1  \
# CTR_D14_Cecum_Digesta_1                    0.979243                 0.985487
# CTR_D14_Cecum_Digesta_2                    0.986637                 0.988639
# CTR_D14_Cecum_Digesta_3                    0.973925                 0.978338
# CTR_D14_Cecum_Digesta_4                    0.984405                 0.990198
# DC_D14_Cecum_Digesta_1                     0.979805                 0.988209
# ...                                             ...                      ...
# HBT_D35_Ileum_Digesta_2                    0.923718                 0.949622
# HBT_D35_Ileum_Digesta_4                    0.884890                 0.920980
# HBT_D03_Ileum_Digesta_2                    0.000000                 0.553854
# CTR_D03_Ileum_Digesta_1                    0.553854                 0.000000
# DC-HBT_D03_Ileum_Digesta_2                 0.668880                 0.614122
#
#                             DC-HBT_D03_Ileum_Digesta_2
# CTR_D14_Cecum_Digesta_1                       0.981708
# CTR_D14_Cecum_Digesta_2                       0.990720
# CTR_D14_Cecum_Digesta_3                       0.972901
# CTR_D14_Cecum_Digesta_4                       0.986209
# DC_D14_Cecum_Digesta_1                        0.989070
# ...                                                ...
# HBT_D35_Ileum_Digesta_2                       0.939087
# HBT_D35_Ileum_Digesta_4                       0.923538
# HBT_D03_Ileum_Digesta_2                       0.668880
# CTR_D03_Ileum_Digesta_1                       0.614122
# DC-HBT_D03_Ileum_Digesta_2                    0.000000
#
# [271 rows x 271 columns]

# %%
cdendrogram_args = {'color_threshold':4.5}

g = nhm(data=digesta_swab_sampled_bray_curtis_full_df, dfc=digesta_swab_sampled_dfrc, figsize=(13, 10), linewidths=0, showyticks=False)
g.hcluster(method='average',optimal_ordering=True)
# fig, plots = g.run(cdendrogram_args=cdendrogram_args)
fig, plots = g.run()
fig.savefig('../figures/heatmap_digesta_swabsampled_samples.png', bbox_inches='tight')

# %%
cdendrogram_args = {'color_threshold':3}

g = nhm(data=mucosa_bray_curtis_full_df, dfc=mucosa_dfrc, figsize=(13, 10), linewidths=0, showyticks=False)
g.hcluster(method='average',optimal_ordering=True)
fig, plots = g.run(cdendrogram_args=cdendrogram_args)
fig.savefig('../figures/mucosa_samples.png', bbox_inches='tight')

# %% [markdown]
# ## 1.3 Raw counts + CLR + low variance filtering

# %%
from skbio.stats.composition import clr

# %%
output_raw_species_excel = pd.read_excel(output_raw_species_excel_path, index_col=0)
output_raw_species_excel = output_raw_species_excel.loc[:, (output_raw_species_excel!= 0).any(axis=0)]
output_raw_species_excel

# %%
output_raw_species_excel = output_raw_species_excel.rename(index=mock_id_dict)

# %%
output_raw_species_excel

# %%
digesta_raw_species = output_raw_species_excel[['Digesta' in s for s in output_raw_species_excel.index]]

digesta_swab_marked_raw_species = output_raw_species_excel[output_raw_species_excel.index.str.contains('Digesta|Swab_Marked')]

# %%
digesta_raw_species

# %%
digesta_swab_marked_raw_species

# %%
# Function from absolute abundances to clr
def to_clr(data):
    data += 1                                  # add pseudocount
    data = data.div(data.sum(axis=0), axis=1)  # relative abund
    return pd.DataFrame(clr(data.T), columns=data.index, index=data.columns).T #clr

# %%
digesta_raw_species_clr_T=to_clr(digesta_raw_species.T)
digesta_swab_marked_raw_species_clr_T=to_clr(digesta_swab_marked_raw_species.T)

# %%
digesta_raw_species_clr=digesta_raw_species_clr_T.T
digesta_swab_marked_raw_species_clr=digesta_swab_marked_raw_species_clr_T.T

# %%
digesta_raw_species_clr_ids = digesta_raw_species_clr.index.tolist()
digesta_swab_marked_raw_species_clr_ids = digesta_swab_marked_raw_species_clr.index.tolist()

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import numpy as np
import sklearn.decomposition, sklearn.cluster
from nheatmap import nhm, scripts
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
import pandas as pd
from skbio.stats.composition import clr


def variance_threshold_selector(data, threshold=1):
    selector = VarianceThreshold(threshold)
    selector.fit(data)
    return data[data.columns[selector.get_support(indices=True)]]

# %%
digesta_raw_species_clr_variancefiltered=variance_threshold_selector(digesta_raw_species_clr,threshold=1.7775)
digesta_raw_species_clr_variancefiltered

# %%
digesta_swab_marked_raw_species_clr_variancefiltered=variance_threshold_selector(digesta_swab_marked_raw_species_clr,threshold=1.67)
digesta_swab_marked_raw_species_clr_variancefiltered

# %%
digesta_raw_dfr=metadata.loc[digesta_raw_species_clr_variancefiltered.index, ['GUT_SECTION', 'AGE', 'TREATMENT']]
digesta_raw_dfr

# %%
digesta_swab_marked_raw_dfr=metadata.loc[digesta_swab_marked_raw_species_clr_variancefiltered.index, ['GUT_SECTION', 'AGE', 'TREATMENT']]
digesta_swab_marked_raw_dfr['GUT_SECTION']=digesta_swab_marked_raw_dfr['GUT_SECTION'].replace('Swab', 'Cloaca')
digesta_swab_marked_raw_dfr

# %%
digesta_raw_species_clr_variancefiltered.columns.tolist()

# %%
with open(mpa_report, "r") as file:
    # Step 2: Read lines and store in a list
    lines = file.readlines()

# %%
species_pylum_name_dict = {}

lines_with_species = [line for line in lines if "s__" in line]
for i in range(len(lines_with_species)):
    s = lines_with_species[i].split("\t")[0].split("|")[-1].split("__")[1]
    p = lines_with_species[i].split("\t")[0].split("|")[1].split("__")[1]
    species_pylum_name_dict[s]=p

species_pylum_name_dict        

# for level_name in lines[9].split("\t")[0].split("|"):
#     level = level_name.split("__")[0]
#     name = level_name.split("__")[1]

# %%
with open(species_id_name_dict_path, "rb") as file:
    # Step 3: Deserialize the pickled dictionary
    species_id_name_dict = pickle.load(file)


species_id_name_dict

# %%
digesta_raw_species_clr_variancefiltered_pylum_names=[]
for i in digesta_raw_species_clr_variancefiltered.columns.tolist():
    species_name = species_id_name_dict[i]
    pylum_name = species_pylum_name_dict[species_name]
    digesta_raw_species_clr_variancefiltered_pylum_names.append(pylum_name)
    
set(digesta_raw_species_clr_variancefiltered_pylum_names)

# %%
import matplotlib.pyplot as plt
plt.hist(digesta_raw_species_clr_variancefiltered_pylum_names)
plt.xticks(rotation=45)
plt.show()

# %%
digesta_swab_marked_raw_species_clr_variancefiltered_pylum_names=[]
for i in digesta_swab_marked_raw_species_clr_variancefiltered.columns.tolist():
    species_name = species_id_name_dict[i]
    pylum_name = species_pylum_name_dict[species_name]
    digesta_swab_marked_raw_species_clr_variancefiltered_pylum_names.append(pylum_name)
    
set(digesta_swab_marked_raw_species_clr_variancefiltered_pylum_names)

# %%
import matplotlib.pyplot as plt
plt.hist(digesta_swab_marked_raw_species_clr_variancefiltered_pylum_names)
plt.xticks(rotation=45)
plt.show()

# %%
digesta_raw_species_dfc = pd.DataFrame(digesta_raw_species_clr_variancefiltered_pylum_names, index=digesta_raw_species_clr_variancefiltered.columns.tolist(),columns=['Phylum'])
digesta_raw_species_dfc

# %%
digesta_swab_marked_raw_species_dfc = pd.DataFrame(digesta_swab_marked_raw_species_clr_variancefiltered_pylum_names, index=digesta_swab_marked_raw_species_clr_variancefiltered.columns.tolist(),columns=['Phylum'])
digesta_swab_marked_raw_species_dfc

# %%
g = nhm(data=digesta_raw_species_clr_variancefiltered.T, dfc=digesta_raw_dfr, dfr=digesta_raw_species_dfc, figsize=(15, 25), linewidths=0, showyticks=False)
g.hcluster(method='average',optimal_ordering=True)
fig, plots = g.run()
fig.savefig('../figures/heatmap_digesta_samples_species.png', bbox_inches='tight')

# %%
g = nhm(data=digesta_swab_marked_raw_species_clr_variancefiltered.T, dfc=digesta_swab_marked_raw_dfr, dfr=digesta_swab_marked_raw_species_dfc, figsize=(15, 25), linewidths=0, showyticks=False)
g.hcluster(method='average',optimal_ordering=True)
fig, plots = g.run()
fig.savefig('../figures/heatmap_digesta_swab_marked_samples_species.png', bbox_inches='tight')

# %%
# pc = sklearn.decomposition.PCA().fit(digesta_clr_variancefiltered)

# %%
# dfr = pd.DataFrame(pc.transform(digesta_clr_variancefiltered)[:, 0], index=['sample '+str(x) for x in np.arange(1, nrows+1)],
#         columns=['PC1'])

# %%
# dfr

# %%
# dfr=metadata.loc[digesta_clr_variancefiltered.index, ['GUT_SECTION', 'AGE', 'TREATMENT']]

# %%
# dfr

# %%
# from sklearn.cluster import KMeans
# wcss = []
# for k in range(6, 50):
#     kmeans = KMeans(n_clusters=k, random_state=42)
#     kmeans.fit(digesta_clr_variancefiltered)
#     wcss.append(kmeans.inertia_)

# # Plot the WCSS against k
# plt.plot(range(6, 50), wcss)
# plt.xlabel('Number of Clusters (k)')
# plt.ylabel('WCSS')
# plt.title('Elbow Method')
# plt.show()

# %%
# dfr['K-means_Cluster'] = sklearn.cluster.KMeans(n_clusters=20).fit_predict(digesta_clr_variancefiltered).astype(str)

# %%
# dfr

# %%
# import hdbscan

# clusterer = hdbscan.HDBSCAN(allow_single_cluster=False, alpha=1.0,
#     approx_min_span_tree=True, core_dist_n_jobs=4, gen_min_span_tree=True,
#     leaf_size=40, min_cluster_size=20, metric='braycurtis')
# clusterer.fit(bray_curtis_full_df)

# %%
# clusterer.labels_
